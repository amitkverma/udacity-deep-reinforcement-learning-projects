# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.16 which is incompatible.

# %%
from unityagents import UnityEnvironment
import numpy as np
import random
import copy
from collections import namedtuple, deque
import time

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726671e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Introduction
# After Deep Q-Networks became a hit, people realized that deep learning methods could be used to solve high-dimensional problems like continuous action spaces. This is a significant obstacle, since most interesting problems in robotic control, etc., fall into this category. Logically, if you discretize your continuous action space too finely, you end up with the same curse of dimensionality problem as before. On the other hand, a naive discretization of the action space throws away valuable information concerning the geometry of the action domain. So Google DeepMind has devised a solid algorithm for tackling the continuous action space problem. Building off the prior work of on Deterministic Policy Gradients, they have produced a policy-gradient actor-critic algorithm called [Deep Deterministic Policy Gradients (DDPG)](https://arxiv.org/abs/1509.02971) that is off-policy and model-free, and that uses some of the deep learning techniques that were introduced along with Deep Q-Networks.
#
# #### 3.1 Algorithm overview
# At its core, DDPG is a policy gradient algorithm that uses a stochastic behavior policy for good exploration but estimates a deterministic target policy, which is much easier to learn. Policy gradient algorithms utilize a form of policy iteration: they evaluate the policy, and then follow the policy gradient to maximize performance. Since DDPG is off-policy and uses a deterministic target policy, this allows for the use of the Deterministic Policy Gradient theorem. DDPG is an actor-critic algorithm as well. it primarily uses two neural networks, one for the actor and one for the critic. These networks compute action predictions for the current state and generate a temporal-difference (TD) error signal each time step. The input of the actor network is the current state, and the output is a single real value representing an action chosen from a continuous action space. The critic’s output is simply the estimated Q-value of the current state and of the action given by the actor. The deterministic policy gradient theorem provides the update rule for the weights of the actor network. The critic network is updated from the gradients obtained from the TD error signal.
#
# #### 3.2 Model Architecture
# DDPG uses four neural networks:
# 1. A Q network
# 2. A deterministic policy network,
# 3. A target Q network
# 4. A target policy network.
#
# The Q network and policy network is very much like simple Advantage Actor-Critic, but in DDPG, the Actor directly maps states to actions (the output of the network directly the output) instead of outputting the probability distribution across a discrete action space.
#
# The target networks are time-delayed copies of their original networks that slowly track the learned networks. Using these target value networks greatly improve stability in learning.
# So, we have the standard Actor & Critic architecture for the deterministic policy network and the Q network

# %%
def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Actor(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed, fc1_units=400, fc2_units=300):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        
        self.bn1 = nn.BatchNorm1d(fc1_units)
        
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state):
        """Build an actor (policy) network that maps states -> actions."""
        x = F.relu(self.bn1(self.fc1(state)))
        
        x = F.relu(self.fc2(x))
        return F.tanh(self.fc3(x))


class Critic(nn.Module):
    """Critic (Value) Model."""

    def __init__(self, state_size, action_size, seed, fcs1_units=400, fc2_units=300):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fcs1_units (int): Number of nodes in the first hidden layer
            fc2_units (int): Number of nodes in the second hidden layer
        """
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        
        self.fcs1 = nn.Linear(state_size, fcs1_units)
        
        self.bn1 = nn.BatchNorm1d(fcs1_units)
        
        self.fc2 = nn.Linear(fcs1_units+action_size, fc2_units)
        self.fc3 = nn.Linear(fc2_units, 1)
        self.reset_parameters()

    def reset_parameters(self):
        self.fcs1.weight.data.uniform_(*hidden_init(self.fcs1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state, action):
        """Build a critic (value) network that maps (state, action) pairs -> Q-values."""
        xs = F.relu(self.bn1(self.fcs1(state)))
        
        x = torch.cat((xs, action), dim=1)
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# ### 4. Replay Buffer
# As used in Deep Q learning (and many other RL algorithms), DDPG also uses a replay buffer to sample experience to update neural network parameters. During each trajectory roll-out, we save all the experience tuples (state, action, reward, next_state) and store them in a finite-sized cache — a “replay buffer.” Then, we sample random mini-batches of experience from the replay buffer when we update the value and policy networks.
#
# Using replay buffer gives us the adventage of removing co-relation between sequential data.

# %%
class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ### 5. Ornstein-Uhlenbeck Process for Noise
# For discrete action spaces, exploration is done via probabilistically selecting a random action (such as epsilon-greedy). For continuous action spaces, exploration is done via adding noise to the action itself. In the DDPG paper, the authors use Ornstein-Uhlenbeck Process to add noise to the action output.

# %%
class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.15, sigma=0.2):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.size = size
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.random.standard_normal(self.size)
        self.state = x + dx
        return self.state

# %% [markdown]
# ### 6. Agent
#
# ![ddpg-algo](./images/ddpg.png)

# %%
class Agent():
    """Interacts with and learns from the environment."""
    
    def __init__(self, state_size, action_size, random_seed):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            random_seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(random_seed)
        
        # Actor Network (w/ Target Network)
        self.actor_local = Actor(state_size, action_size, random_seed).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed).to(device)
        self.actor_optimizer = optim.Adam(self.actor_local.parameters(), lr=LR_ACTOR)

        # Critic Network (w/ Target Network)
        self.critic_local = Critic(state_size, action_size, random_seed).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed).to(device)
        self.critic_optimizer = optim.Adam(self.critic_local.parameters(), lr=LR_CRITIC, weight_decay=WEIGHT_DECAY)

        # Noise process
        self.noise = OUNoise(action_size, random_seed)
        
        # Replay memory
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, random_seed)
    
    def step(self, state, action, reward, next_state, done):
        """Save experience in replay memory, and use random sample from buffer to learn."""
        # Save experience / reward
        self.memory.add(state, action, reward, next_state, done)

    def act(self, state, add_noise=True):
        """Returns actions for given state as per current policy."""
        state = torch.from_numpy(state).float().to(device)
        self.actor_local.eval()
        with torch.no_grad():
            action = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()
        if add_noise:
            action += self.noise.sample()
        return np.clip(action, -1, 1)

    def reset(self):
        self.noise.reset()

    def start_learn(self):
        if len(self.memory) > BATCH_SIZE:
            experiences = self.memory.sample()
            self.learn(experiences, GAMMA)
        
    def learn(self, experiences, gamma):
        """Update policy and value parameters using given batch of experience tuples.
        Q_targets = r + γ * critic_target(next_state, actor_target(next_state))
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value
        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # ---------------------------- update critic ---------------------------- #
        # Get predicted next-state actions and Q values from target models
        actions_next = self.actor_target(next_states)
        Q_targets_next = self.critic_target(next_states, actions_next)
        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))
        # Compute critic loss
        Q_expected = self.critic_local(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm(self.critic_local.parameters(), 1)
        self.critic_optimizer.step()

        # ---------------------------- update actor ---------------------------- #
        # Compute actor loss
        actions_pred = self.actor_local(states)
        actor_loss = -self.critic_local(states, actions_pred).mean()
        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # ----------------------- update target networks ----------------------- #
        self.soft_update(self.critic_local, self.critic_target, TAU)
        self.soft_update(self.actor_local, self.actor_target, TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target
        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

# %% [markdown]
# ### 7. Initialize Model

# %%
# Hyperparameters

GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-3         # learning rate of the actor 
LR_CRITIC = 1e-3        # learning rate of the critic
WEIGHT_DECAY = 0.0000     # L2 weight decay
BATCH_SIZE = 1024         # minibatch size
BUFFER_SIZE = int(1e6)  # replay buffer size
RANDOM_SEED=11

agent = Agent(state_size=state_size, action_size=action_size, random_seed=RANDOM_SEED)

# %% [markdown]
# ### 8. Train

# %%
def ddpg(n_episodes=2000, max_t=1000, print_every=10, learn_every=20, num_learn=10, goal_score=30):
    total_scores_deque = deque(maxlen=100)
    total_scores = []
    
    for i_episode in range(1, n_episodes+1):
        # Reset Env and Agent
        env_info = env.reset(train_mode=True)[brain_name]       # reset the environment    
        states = env_info.vector_observations                   # get the current state (for each agent)
        scores = np.zeros(num_agents)                            # initialize the score (for each agent)
        agent.reset()
        
        start_time = time.time()
        
        for t in range(max_t):
            actions = agent.act(states)
            
            env_info = env.step(actions)[brain_name]            # send all actions to the environment
            next_states = env_info.vector_observations          # get next state (for each agent)
            rewards = env_info.rewards                          # get reward (for each agent)
            
            dones = env_info.local_done                         # see if episode finished
            
            for state, action, reward, next_state, done in zip(states, actions, rewards, next_states, dones):
                agent.step(state, action, reward, next_state, done) # send actions to the agent
            
            scores += env_info.rewards                           # update the score (for each agent)
            states = next_states                                # roll over states to next time step
            
            if t%learn_every == 0:
                for _ in range(num_learn):
                    agent.start_learn()
            
            if np.any(dones):                                   # exit loop if episode finished
                break
    
        mean_score = np.mean(scores)
        min_score = np.min(scores)
        max_score = np.max(scores)
        total_scores_deque.append(mean_score)
        total_scores.append(mean_score)
        total_average_score = np.mean(total_scores_deque)
        duration = time.time() - start_time
        
        print('\rEpisode {}\tTotal Average Score: {:.2f}\tMean: {:.2f}\tMin: {:.2f}\tMax: {:.2f}\tDuration: {:.2f}'
              .format(i_episode, total_average_score, mean_score, min_score, max_score, duration))

        if i_episode % print_every == 0:
            torch.save(agent.actor_local.state_dict(), 'checkpoints/checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoints/checkpoint_critic.pth')
            print('\rEpisode {}\tTotal Average Score: {:.2f}'.format(i_episode, total_average_score))  
            
        if total_average_score >= goal_score and i_episode >= 100:
            print('Problem Solved after {} epsisodes!! Total Average score: {:.2f}'.format(i_episode, total_average_score))
            torch.save(agent.actor_local.state_dict(), 'checkpoints/checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoints/checkpoint_critic.pth')
            break
    
    return total_scores

scores = ddpg()
# Out:
# Episode 1	Total Average Score: 1.00	Mean: 1.00	Min: 1.00	Max: 1.00	Duration: 2.86
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:82: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# Episode 2	Total Average Score: 0.63	Mean: 0.27	Min: 0.27	Max: 0.27	Duration: 20.04
# Episode 3	Total Average Score: 0.42	Mean: 0.00	Min: 0.00	Max: 0.00	Duration: 20.75
# Episode 4	Total Average Score: 0.60	Mean: 1.12	Min: 1.12	Max: 1.12	Duration: 20.73
# Episode 5	Total Average Score: 0.52	Mean: 0.22	Min: 0.22	Max: 0.22	Duration: 21.02
# Episode 6	Total Average Score: 0.56	Mean: 0.77	Min: 0.77	Max: 0.77	Duration: 21.04
# Episode 7	Total Average Score: 0.52	Mean: 0.23	Min: 0.23	Max: 0.23	Duration: 20.98
# Episode 8	Total Average Score: 0.46	Mean: 0.04	Min: 0.04	Max: 0.04	Duration: 20.91
# Episode 9	Total Average Score: 0.44	Mean: 0.31	Min: 0.31	Max: 0.31	Duration: 20.91
# Episode 10	Total Average Score: 0.49	Mean: 0.90	Min: 0.90	Max: 0.90	Duration: 21.06
# Episode 10	Total Average Score: 0.49
# Episode 11	Total Average Score: 0.63	Mean: 2.12	Min: 2.12	Max: 2.12	Duration: 21.01
# Episode 12	Total Average Score: 0.82	Mean: 2.89	Min: 2.89	Max: 2.89	Duration: 21.09
# Episode 13	Total Average Score: 0.89	Mean: 1.72	Min: 1.72	Max: 1.72	Duration: 21.23
# Episode 14	Total Average Score: 0.94	Mean: 1.56	Min: 1.56	Max: 1.56	Duration: 21.18
# Episode 15	Total Average Score: 0.93	Mean: 0.74	Min: 0.74	Max: 0.74	Duration: 21.18
# Episode 16	Total Average Score: 1.01	Mean: 2.26	Min: 2.26	Max: 2.26	Duration: 21.30
# Episode 17	Total Average Score: 1.14	Mean: 3.30	Min: 3.30	Max: 3.30	Duration: 21.34
# Episode 18	Total Average Score: 1.14	Mean: 1.02	Min: 1.02	Max: 1.02	Duration: 21.44
# Episode 19	Total Average Score: 1.20	Mean: 2.39	Min: 2.39	Max: 2.39	Duration: 21.43
# Episode 20	Total Average Score: 1.30	Mean: 3.20	Min: 3.20	Max: 3.20	Duration: 21.45
# Episode 20	Total Average Score: 1.30
# Episode 21	Total Average Score: 1.32	Mean: 1.74	Min: 1.74	Max: 1.74	Duration: 21.42
# Episode 22	Total Average Score: 1.31	Mean: 1.04	Min: 1.04	Max: 1.04	Duration: 21.43
# Episode 23	Total Average Score: 1.40	Mean: 3.36	Min: 3.36	Max: 3.36	Duration: 21.42
# Episode 24	Total Average Score: 1.46	Mean: 2.87	Min: 2.87	Max: 2.87	Duration: 21.21
# Episode 25	Total Average Score: 1.55	Mean: 3.60	Min: 3.60	Max: 3.60	Duration: 21.56
# Episode 26	Total Average Score: 1.77	Mean: 7.40	Min: 7.40	Max: 7.40	Duration: 21.22
# Episode 27	Total Average Score: 1.84	Mean: 3.64	Min: 3.64	Max: 3.64	Duration: 21.16
# Episode 28	Total Average Score: 1.95	Mean: 4.76	Min: 4.76	Max: 4.76	Duration: 21.48
# Episode 29	Total Average Score: 2.11	Mean: 6.64	Min: 6.64	Max: 6.64	Duration: 21.48
# Episode 30	Total Average Score: 2.11	Mean: 2.18	Min: 2.18	Max: 2.18	Duration: 21.43
# Episode 30	Total Average Score: 2.11
# Episode 31	Total Average Score: 2.17	Mean: 3.86	Min: 3.86	Max: 3.86	Duration: 21.39
# Episode 32	Total Average Score: 2.23	Mean: 4.33	Min: 4.33	Max: 4.33	Duration: 21.21
# Episode 33	Total Average Score: 2.32	Mean: 5.23	Min: 5.23	Max: 5.23	Duration: 21.47
# Episode 34	Total Average Score: 2.34	Mean: 2.80	Min: 2.80	Max: 2.80	Duration: 21.64
# Episode 35	Total Average Score: 2.42	Mean: 5.34	Min: 5.34	Max: 5.34	Duration: 21.69
# Episode 36	Total Average Score: 2.51	Mean: 5.48	Min: 5.48	Max: 5.48	Duration: 21.57
# Episode 37	Total Average Score: 2.53	Mean: 3.16	Min: 3.16	Max: 3.16	Duration: 21.59
# Episode 38	Total Average Score: 2.66	Mean: 7.45	Min: 7.45	Max: 7.45	Duration: 21.96
# Episode 39	Total Average Score: 2.78	Mean: 7.35	Min: 7.35	Max: 7.35	Duration: 21.90
# Episode 40	Total Average Score: 2.95	Mean: 9.55	Min: 9.55	Max: 9.55	Duration: 21.82
# Episode 40	Total Average Score: 2.95
# Episode 41	Total Average Score: 2.96	Mean: 3.57	Min: 3.57	Max: 3.57	Duration: 21.82
# Episode 42	Total Average Score: 3.21	Mean: 13.38	Min: 13.38	Max: 13.38	Duration: 21.80
# Episode 43	Total Average Score: 3.37	Mean: 10.13	Min: 10.13	Max: 10.13	Duration: 21.79
# Episode 44	Total Average Score: 3.53	Mean: 10.60	Min: 10.60	Max: 10.60	Duration: 21.72
# Episode 45	Total Average Score: 3.60	Mean: 6.50	Min: 6.50	Max: 6.50	Duration: 21.73
# Episode 46	Total Average Score: 3.58	Mean: 2.77	Min: 2.77	Max: 2.77	Duration: 21.67
# Episode 47	Total Average Score: 3.75	Mean: 11.49	Min: 11.49	Max: 11.49	Duration: 21.71
# Episode 48	Total Average Score: 3.92	Mean: 11.77	Min: 11.77	Max: 11.77	Duration: 21.71
# Episode 49	Total Average Score: 4.13	Mean: 14.08	Min: 14.08	Max: 14.08	Duration: 21.75
# Episode 50	Total Average Score: 4.26	Mean: 11.03	Min: 11.03	Max: 11.03	Duration: 21.63
# Episode 50	Total Average Score: 4.26
# Episode 51	Total Average Score: 4.40	Mean: 11.06	Min: 11.06	Max: 11.06	Duration: 21.50
# Episode 52	Total Average Score: 4.61	Mean: 15.39	Min: 15.39	Max: 15.39	Duration: 21.60
# Episode 53	Total Average Score: 4.76	Mean: 12.67	Min: 12.67	Max: 12.67	Duration: 21.72
# Episode 54	Total Average Score: 4.91	Mean: 12.80	Min: 12.80	Max: 12.80	Duration: 21.53
# Episode 55	Total Average Score: 5.06	Mean: 13.37	Min: 13.37	Max: 13.37	Duration: 21.66
# Episode 56	Total Average Score: 5.28	Mean: 17.04	Min: 17.04	Max: 17.04	Duration: 21.58
# Episode 57	Total Average Score: 5.57	Mean: 22.25	Min: 22.25	Max: 22.25	Duration: 21.55
# Episode 58	Total Average Score: 5.71	Mean: 13.73	Min: 13.73	Max: 13.73	Duration: 21.65
# Episode 59	Total Average Score: 5.70	Mean: 5.10	Min: 5.10	Max: 5.10	Duration: 21.69
# Episode 60	Total Average Score: 5.95	Mean: 20.70	Min: 20.70	Max: 20.70	Duration: 21.61
# Episode 60	Total Average Score: 5.95
# Episode 61	Total Average Score: 6.10	Mean: 14.57	Min: 14.57	Max: 14.57	Duration: 21.61
# Episode 62	Total Average Score: 6.15	Mean: 9.77	Min: 9.77	Max: 9.77	Duration: 21.71
# Episode 63	Total Average Score: 6.49	Mean: 27.36	Min: 27.36	Max: 27.36	Duration: 21.82
# Episode 64	Total Average Score: 6.57	Mean: 11.23	Min: 11.23	Max: 11.23	Duration: 21.58
# Episode 65	Total Average Score: 6.88	Mean: 27.21	Min: 27.21	Max: 27.21	Duration: 21.61
# Episode 66	Total Average Score: 6.94	Mean: 10.70	Min: 10.70	Max: 10.70	Duration: 21.75
# Episode 67	Total Average Score: 6.92	Mean: 5.66	Min: 5.66	Max: 5.66	Duration: 21.72
# Episode 68	Total Average Score: 7.12	Mean: 20.31	Min: 20.31	Max: 20.31	Duration: 21.83
# Episode 69	Total Average Score: 7.26	Mean: 16.97	Min: 16.97	Max: 16.97	Duration: 21.78
# Episode 70	Total Average Score: 7.55	Mean: 27.21	Min: 27.21	Max: 27.21	Duration: 21.88
# Episode 70	Total Average Score: 7.55
# Episode 71	Total Average Score: 7.80	Mean: 25.65	Min: 25.65	Max: 25.65	Duration: 21.81
# Episode 72	Total Average Score: 8.04	Mean: 24.96	Min: 24.96	Max: 24.96	Duration: 21.86
# Episode 73	Total Average Score: 8.33	Mean: 29.44	Min: 29.44	Max: 29.44	Duration: 22.00
# Episode 74	Total Average Score: 8.47	Mean: 18.61	Min: 18.61	Max: 18.61	Duration: 21.89
# Episode 75	Total Average Score: 8.45	Mean: 6.78	Min: 6.78	Max: 6.78	Duration: 21.84
# Episode 76	Total Average Score: 8.69	Mean: 26.46	Min: 26.46	Max: 26.46	Duration: 21.90
# Episode 77	Total Average Score: 8.99	Mean: 32.42	Min: 32.42	Max: 32.42	Duration: 22.05
# Episode 78	Total Average Score: 9.16	Mean: 22.14	Min: 22.14	Max: 22.14	Duration: 22.09
# Episode 79	Total Average Score: 9.28	Mean: 18.08	Min: 18.08	Max: 18.08	Duration: 22.07
# Episode 80	Total Average Score: 9.49	Mean: 26.51	Min: 26.51	Max: 26.51	Duration: 22.12
# Episode 80	Total Average Score: 9.49
# Episode 81	Total Average Score: 9.57	Mean: 15.81	Min: 15.81	Max: 15.81	Duration: 22.03
# Episode 82	Total Average Score: 9.80	Mean: 28.57	Min: 28.57	Max: 28.57	Duration: 22.19
# Episode 83	Total Average Score: 10.08	Mean: 33.31	Min: 33.31	Max: 33.31	Duration: 22.09
# Episode 84	Total Average Score: 10.36	Mean: 33.58	Min: 33.58	Max: 33.58	Duration: 21.98
# Episode 85	Total Average Score: 10.53	Mean: 24.25	Min: 24.25	Max: 24.25	Duration: 22.63
# Episode 86	Total Average Score: 10.81	Mean: 34.88	Min: 34.88	Max: 34.88	Duration: 22.09
# Episode 87	Total Average Score: 11.09	Mean: 34.92	Min: 34.92	Max: 34.92	Duration: 22.11
# Episode 88	Total Average Score: 11.11	Mean: 12.72	Min: 12.72	Max: 12.72	Duration: 22.07
# Episode 89	Total Average Score: 11.34	Mean: 31.83	Min: 31.83	Max: 31.83	Duration: 22.02
# Episode 90	Total Average Score: 11.52	Mean: 27.21	Min: 27.21	Max: 27.21	Duration: 22.26
# Episode 90	Total Average Score: 11.52
# Episode 91	Total Average Score: 11.77	Mean: 35.02	Min: 35.02	Max: 35.02	Duration: 22.31
# Episode 92	Total Average Score: 11.87	Mean: 20.21	Min: 20.21	Max: 20.21	Duration: 22.25
# Episode 93	Total Average Score: 12.10	Mean: 33.85	Min: 33.85	Max: 33.85	Duration: 22.23
# Episode 94	Total Average Score: 12.11	Mean: 13.34	Min: 13.34	Max: 13.34	Duration: 22.22
# Episode 95	Total Average Score: 12.21	Mean: 20.91	Min: 20.91	Max: 20.91	Duration: 22.24
# Episode 96	Total Average Score: 12.41	Mean: 31.61	Min: 31.61	Max: 31.61	Duration: 22.43
# Episode 97	Total Average Score: 12.58	Mean: 29.04	Min: 29.04	Max: 29.04	Duration: 22.34
# Episode 98	Total Average Score: 12.81	Mean: 35.21	Min: 35.21	Max: 35.21	Duration: 22.34
# Episode 99	Total Average Score: 12.99	Mean: 30.71	Min: 30.71	Max: 30.71	Duration: 22.42
# Episode 100	Total Average Score: 13.22	Mean: 35.70	Min: 35.70	Max: 35.70	Duration: 22.35
# Episode 100	Total Average Score: 13.22
# Episode 101	Total Average Score: 13.53	Mean: 31.62	Min: 31.62	Max: 31.62	Duration: 22.35
# Episode 102	Total Average Score: 13.88	Mean: 35.40	Min: 35.40	Max: 35.40	Duration: 22.54
# Episode 103	Total Average Score: 14.23	Mean: 35.61	Min: 35.61	Max: 35.61	Duration: 22.36
# Episode 104	Total Average Score: 14.51	Mean: 28.49	Min: 28.49	Max: 28.49	Duration: 22.36
# Episode 105	Total Average Score: 14.79	Mean: 28.46	Min: 28.46	Max: 28.46	Duration: 22.26
# Episode 106	Total Average Score: 15.15	Mean: 36.50	Min: 36.50	Max: 36.50	Duration: 22.08
# Episode 107	Total Average Score: 15.50	Mean: 35.43	Min: 35.43	Max: 35.43	Duration: 22.14
# Episode 108	Total Average Score: 15.84	Mean: 34.01	Min: 34.01	Max: 34.01	Duration: 22.17
# Episode 109	Total Average Score: 16.16	Mean: 32.89	Min: 32.89	Max: 32.89	Duration: 22.14
# Episode 110	Total Average Score: 16.49	Mean: 33.42	Min: 33.42	Max: 33.42	Duration: 22.33
# Episode 110	Total Average Score: 16.49
# Episode 111	Total Average Score: 16.78	Mean: 30.76	Min: 30.76	Max: 30.76	Duration: 22.49
# Episode 112	Total Average Score: 17.09	Mean: 33.87	Min: 33.87	Max: 33.87	Duration: 22.45
# Episode 113	Total Average Score: 17.44	Mean: 36.80	Min: 36.80	Max: 36.80	Duration: 22.33
# Episode 114	Total Average Score: 17.79	Mean: 36.95	Min: 36.95	Max: 36.95	Duration: 22.41
# Episode 115	Total Average Score: 18.17	Mean: 38.20	Min: 38.20	Max: 38.20	Duration: 22.43
# Episode 116	Total Average Score: 18.48	Mean: 34.04	Min: 34.04	Max: 34.04	Duration: 22.33
# Episode 117	Total Average Score: 18.82	Mean: 37.33	Min: 37.33	Max: 37.33	Duration: 22.37
# Episode 118	Total Average Score: 19.15	Mean: 33.53	Min: 33.53	Max: 33.53	Duration: 22.34
# Episode 119	Total Average Score: 19.49	Mean: 36.27	Min: 36.27	Max: 36.27	Duration: 22.33
# Episode 120	Total Average Score: 19.79	Mean: 33.26	Min: 33.26	Max: 33.26	Duration: 22.37
# Episode 120	Total Average Score: 19.79
# Episode 121	Total Average Score: 20.14	Mean: 37.33	Min: 37.33	Max: 37.33	Duration: 22.46
# Episode 122	Total Average Score: 20.48	Mean: 34.90	Min: 34.90	Max: 34.90	Duration: 22.45
# Episode 123	Total Average Score: 20.83	Mean: 38.32	Min: 38.32	Max: 38.32	Duration: 22.53
# Episode 124	Total Average Score: 21.13	Mean: 32.43	Min: 32.43	Max: 32.43	Duration: 22.55
# Episode 125	Total Average Score: 21.46	Mean: 37.36	Min: 37.36	Max: 37.36	Duration: 23.12
# Episode 126	Total Average Score: 21.73	Mean: 34.04	Min: 34.04	Max: 34.04	Duration: 22.66
# Episode 127	Total Average Score: 22.07	Mean: 37.55	Min: 37.55	Max: 37.55	Duration: 22.39
# Episode 128	Total Average Score: 22.32	Mean: 29.79	Min: 29.79	Max: 29.79	Duration: 22.40
# Episode 129	Total Average Score: 22.64	Mean: 38.80	Min: 38.80	Max: 38.80	Duration: 22.46
# Episode 130	Total Average Score: 22.91	Mean: 29.30	Min: 29.30	Max: 29.30	Duration: 22.49
# Episode 130	Total Average Score: 22.91
# Episode 131	Total Average Score: 23.26	Mean: 38.75	Min: 38.75	Max: 38.75	Duration: 22.52
# Episode 132	Total Average Score: 23.41	Mean: 18.99	Min: 18.99	Max: 18.99	Duration: 22.81
# Episode 133	Total Average Score: 23.74	Mean: 37.96	Min: 37.96	Max: 37.96	Duration: 22.74
# Episode 134	Total Average Score: 24.00	Mean: 29.31	Min: 29.31	Max: 29.31	Duration: 22.60
# Episode 135	Total Average Score: 24.30	Mean: 35.27	Min: 35.27	Max: 35.27	Duration: 22.67
# Episode 136	Total Average Score: 24.49	Mean: 24.74	Min: 24.74	Max: 24.74	Duration: 22.61
# Episode 137	Total Average Score: 24.80	Mean: 33.54	Min: 33.54	Max: 33.54	Duration: 22.56
# Episode 138	Total Average Score: 25.00	Mean: 27.53	Min: 27.53	Max: 27.53	Duration: 22.83
# Episode 139	Total Average Score: 25.27	Mean: 34.45	Min: 34.45	Max: 34.45	Duration: 23.01
# Episode 140	Total Average Score: 25.53	Mean: 35.49	Min: 35.49	Max: 35.49	Duration: 22.75
# Episode 140	Total Average Score: 25.53
# Episode 141	Total Average Score: 25.81	Mean: 31.82	Min: 31.82	Max: 31.82	Duration: 22.75
# Episode 142	Total Average Score: 25.96	Mean: 28.52	Min: 28.52	Max: 28.52	Duration: 22.63
# Episode 143	Total Average Score: 26.23	Mean: 36.56	Min: 36.56	Max: 36.56	Duration: 22.56
# Episode 144	Total Average Score: 26.45	Mean: 32.75	Min: 32.75	Max: 32.75	Duration: 22.90
# Episode 145	Total Average Score: 26.76	Mean: 37.33	Min: 37.33	Max: 37.33	Duration: 23.15
# Episode 146	Total Average Score: 26.85	Mean: 12.39	Min: 12.39	Max: 12.39	Duration: 23.23
# Episode 147	Total Average Score: 27.07	Mean: 33.01	Min: 33.01	Max: 33.01	Duration: 23.00
# Episode 148	Total Average Score: 27.24	Mean: 28.96	Min: 28.96	Max: 28.96	Duration: 22.91
# Episode 149	Total Average Score: 27.42	Mean: 31.74	Min: 31.74	Max: 31.74	Duration: 22.97
# Episode 150	Total Average Score: 27.66	Mean: 34.99	Min: 34.99	Max: 34.99	Duration: 22.96
# Episode 150	Total Average Score: 27.66
# Episode 151	Total Average Score: 27.85	Mean: 30.25	Min: 30.25	Max: 30.25	Duration: 23.05
# Episode 152	Total Average Score: 28.04	Mean: 34.26	Min: 34.26	Max: 34.26	Duration: 23.02
# Episode 153	Total Average Score: 28.22	Mean: 30.94	Min: 30.94	Max: 30.94	Duration: 23.12
# Episode 154	Total Average Score: 28.43	Mean: 34.20	Min: 34.20	Max: 34.20	Duration: 22.94
# Episode 155	Total Average Score: 28.64	Mean: 33.95	Min: 33.95	Max: 33.95	Duration: 23.36
# Episode 156	Total Average Score: 28.78	Mean: 31.22	Min: 31.22	Max: 31.22	Duration: 23.17
# Episode 157	Total Average Score: 28.89	Mean: 33.63	Min: 33.63	Max: 33.63	Duration: 22.96
# Episode 158	Total Average Score: 29.12	Mean: 35.96	Min: 35.96	Max: 35.96	Duration: 23.25
# Episode 159	Total Average Score: 29.45	Mean: 38.29	Min: 38.29	Max: 38.29	Duration: 23.24
# Episode 160	Total Average Score: 29.56	Mean: 31.76	Min: 31.76	Max: 31.76	Duration: 23.37
# Episode 160	Total Average Score: 29.56
# Episode 161	Total Average Score: 29.78	Mean: 36.21	Min: 36.21	Max: 36.21	Duration: 23.42
# Episode 162	Total Average Score: 30.01	Mean: 33.68	Min: 33.68	Max: 33.68	Duration: 23.09
# Problem Solved after 162 epsisodes!! Total Average score: 30.01

# %% [markdown]
# ### 9. Plot the scores

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.savefig('results/ddpg_result.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 10. Model in action

# %%
# Load the saved weights into Pytorch model
agent.actor_local.load_state_dict(torch.load('checkpoints/checkpoint_actor.pth', map_location='cpu'))
agent.critic_local.load_state_dict(torch.load('checkpoints/checkpoint_critic.pth', map_location='cpu'))

env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)

while True:
    actions = agent.act(states)                        # select actions from loaded model agent
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score: {}'.format(np.mean(scores)))
# Out:
# Total score: 38.439999140799046

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()
